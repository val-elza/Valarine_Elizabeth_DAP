# %%
#import pandas library
import pandas as pd

#import the second notebook file
# %mongo.ipynb

#call the dataframe from the second notebook file
#df = pd.DataFrame(sectors_clean)
world_data = pd.DataFrame(Final, fpath="C:/Users/prith/Desktop/mongo.ipynb")

# %%
#Installing necessary Imports modules/library
from pymongo import MongoClient #pymongo to connect to an existing document collection

import pymongo

from zipfile import * # importing Zipfiles

import pandas as pd #Importing pandas

import requests #Make a request to a web page

# %% [markdown]
# # Upload and retrieve data from postgreSQL

# %%
import psycopg2
try:
    dbConnection = psycopg2.connect(
        user = "dap",
        password = "dap",
        host = "127.0.0.1",
        port = "5432",
        database = "postgres")

    dbConnection.autocommit = True
    cursor = dbConnection.cursor()
    cursor.execute("create database dap_4")
    cursor.execute("SELECT version();")
    record = cursor.fetchone()
    print("You are connected to - ", record, "\n")
    print("Database dap_project created successfully !!")
except (psycopg2.Error) as dbError :
    print("Error while connecting to PostgreSQL", dbError);
# Out:
# You are connected to -  ('PostgreSQL 15.1 (Debian 15.1-1.pgdg110+1) on x86_64-pc-linux-gnu, compiled by gcc (Debian 10.2.1-6) 10.2.1 20210110, 64-bit',)
#
# Database dap_project created successfully !!

# %%
import sqlalchemy
engine =sqlalchemy.create_engine('postgresql://dap:dap@localhost:5432/dap_final')
con = engine.connect()

# %%
# drop table if it already exists
cursor.execute('drop table if exists dapdata')

sql = '''CREATE TABLE dapdata(id serial , country character varying(255), year character varying(5),
export_gs_idxas double precision,fdi_netflow_idxas double precision,goldreserve_idxas double precision,grants_idxas double precision,
imf_credit_idxas double precision,import_gs_idxas double precision,inflation_idxas double precision,
personalremmitance_idxas double precision,poverty_ratio_in_population_idxas double precision,
tourism_expenditures_idxas double precision,unemployment_idxas double precision);'''

cursor.execute(sql)

# %%
for i in range (len(world_data.index)):
    data =[]
        
    for col in world_data:
        data.append(str(world_data[col][i]))
    insrt_scrpt = """Insert into dapdata (country,year,export_gs_idxas,fdi_netflow_idxas,goldreserve_idxas,grants_idxas,imf_credit_idxas,import_gs_idxas,inflation_idxas,
personalremmitance_idxas,poverty_ratio_in_population_idxas,tourism_expenditures_idxas,unemployment_idxas)  
            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"""
    cursor.execute(insrt_scrpt,data)
    
    #break
    dbConnection.commit()

# %%
import pandas as pd
world_DATASET = pd.read_sql('select * from dapdata', con=dbConnection)
world_DATASET
# Out:
#         id   country  year  export_gs_idxas  fdi_netflow_idxas  \
# 0        1     Aruba  2014        78.262610       2.506181e+08
# 1        2     Aruba  2015        72.850679      -2.877586e+07
# 2        3     Aruba  2016        71.821756       2.755127e+07
# 3        4     Aruba  2017        72.556459       1.624636e+08
# 4        5     Aruba  2018        73.796232       1.359212e+08
# ...    ...       ...   ...              ...                ...
# 2115  2116  Zimbabwe  2017        19.658905       3.071877e+08
# 2116  2117  Zimbabwe  2018        28.049757       7.178653e+08
# 2117  2118  Zimbabwe  2019        31.251040       2.495000e+08
# 2118  2119  Zimbabwe  2020        37.202235       1.503600e+08
# 2119  2120  Zimbabwe  2021        39.401279       6.137578e+10
#
#       goldreserve_idxas  grants_idxas  imf_credit_idxas  import_gs_idxas  \
# 0          6.803510e+08  1.366157e+09      5.220875e+09        84.607686
# ...
